# %% [markdown]
# # Missigness Analysis of Patient Data for Baseline Variables

# %% [markdown]
# **Questions:**
#
# - Do we have multiple observations of the same variable? --> No each oberservation, test, etc is only done once
# - What is the timeframe of the observation? --> no time series data in baseline variables

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load Data

# %%
path = 'C:/Users/Elly/Dropbox/Biotronik/data/merged'
main_file = 'baseline_information'
main_data = pd.read_csv('{}/{}.csv'.format(path, main_file))
main_data
# Out:
#                 subjid  age     sex  incl03  incl04  incl05  excl01  excl02  \
# 0     C1503-AUS012-001   49    Male     1.0     1.0     1.0     0.0     0.0
# 1     C1503-AUS012-002   70    Male     1.0     1.0     1.0     0.0     0.0
# 2     C1503-AUS012-003   46    Male     1.0     1.0     1.0     0.0     0.0
# 3     C1503-AUS012-004   40    Male     1.0     1.0     1.0     0.0     0.0
# 4     C1503-AUS012-005   65  Female     1.0     1.0     1.0     0.0     0.0
# ...                ...  ...     ...     ...     ...     ...     ...     ...
# 2061  C1503-ZAF003-006   72    Male     1.0     1.0     1.0     0.0     0.0
# 2062  C1503-ZAF003-007   55    Male     1.0     1.0     1.0     0.0     0.0
# 2063  C1503-ZAF003-008   41    Male     1.0     1.0     1.0     0.0     0.0
# 2064  C1503-ZAF003-009   55    Male     1.0     1.0     1.0     0.0     0.0
# 2065  C1503-ZAF003-010   65    Male     1.0     1.0     1.0     0.0     0.0
#
# ...
